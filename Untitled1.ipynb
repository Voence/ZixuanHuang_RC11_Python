# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import seaborn as sns

# %%
data= pd.read_csv('C:/Users/Voence/Desktop/python_work/ZixuanHuang_RC11_Python/you-datascientist-master/happiness_with_continent.csv')

# %%
data.head(100)
# Out:
#    Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0   Afghanistan  2008     3.723590            7.168690        0.450662
# 1   Afghanistan  2009     4.401778            7.333790        0.552308
# 2   Afghanistan  2010     4.758381            7.386629        0.539075
# 3   Afghanistan  2011     3.831719            7.415019        0.521104
# 4   Afghanistan  2012     3.782938            7.517126        0.520637
# ..          ...   ...          ...                 ...             ...
# 95      Bahrain  2009     5.700523           10.614406        0.904143
# 96      Bahrain  2010     5.936869           10.610797        0.877115
# 97      Bahrain  2011     4.823976           10.600740        0.907868
# 98      Bahrain  2012     5.027187           10.620359        0.911350
# 99      Bahrain  2013     6.689711           10.661490        0.883781
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
data.tail(5)
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 1699     Zimbabwe  2014     4.184451            7.562753        0.765839
# 1700     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1701     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1702     Zimbabwe  2017     3.638300            7.549491        0.754147
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1699                         52.380001                      0.642034
# 1700                         53.799999                      0.667193
# 1701                         54.400002                      0.732971
# 1702                         55.000000                      0.752826
# 1703                         55.599998                      0.762675
#
#       Generosity  Perceptions of corruption  Positive affect  ...  \
# ...

# %%
data.sample(5)
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 285          Chad  2015     4.322675            7.633903        0.751252
# 1693     Zimbabwe  2008     3.174264            7.102516        0.843475
# 142        Belize  2007     6.450644            8.974969        0.872267
# 675          Iran  2016     4.652731            9.825400        0.566281
# 354    Costa Rica  2010     7.271054            9.472704        0.915141
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 285                          46.700001                      0.474361
# 1693                         44.139999                      0.343556
# 142                          61.599998                      0.705306
# 675                          65.400002                      0.773304
# 354                          69.699997                      0.881030
#
#       Generosity  Perceptions of corruption  Positive affect  ...  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b8f1ed6aa403> in <module>
# ----> 1 DataFrame.head(5)
#
# NameError: name 'DataFrame' is not defined
