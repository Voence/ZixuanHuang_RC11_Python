# %%
import os

# %%
from PIL import Image

# %%
fileName=os.listdir('D:\\WORKSHOP2\\100-200Sec_model3\\')

# %%
for img in fileName:

    print ('D:\\WORKSHOP2\\100-200Sec_model\\'+img)
# Out:
# D:\WORKSHOP2\100-200Sec_model\00.jpg
# D:\WORKSHOP2\100-200Sec_model\01.jpg
# D:\WORKSHOP2\100-200Sec_model\02.jpg
# D:\WORKSHOP2\100-200Sec_model\03.jpg
# D:\WORKSHOP2\100-200Sec_model\04.jpg
# D:\WORKSHOP2\100-200Sec_model\05.jpg
# D:\WORKSHOP2\100-200Sec_model\06.jpg
# D:\WORKSHOP2\100-200Sec_model\07.jpg
# D:\WORKSHOP2\100-200Sec_model\08.jpg
# D:\WORKSHOP2\100-200Sec_model\09.jpg
# D:\WORKSHOP2\100-200Sec_model\1.jpg
# D:\WORKSHOP2\100-200Sec_model\10.jpg
# D:\WORKSHOP2\100-200Sec_model\100.jpg
# D:\WORKSHOP2\100-200Sec_model\102.jpg
# D:\WORKSHOP2\100-200Sec_model\104.jpg
# D:\WORKSHOP2\100-200Sec_model\106.jpg
# D:\WORKSHOP2\100-200Sec_model\108.jpg
# D:\WORKSHOP2\100-200Sec_model\11.jpg
# D:\WORKSHOP2\100-200Sec_model\110.jpg
# D:\WORKSHOP2\100-200Sec_model\112.jpg
# D:\WORKSHOP2\100-200Sec_model\114.jpg
# D:\WORKSHOP2\100-200Sec_model\116.jpg
# D:\WORKSHOP2\100-200Sec_model\118.jpg
# D:\WORKSHOP2\100-200Sec_model\12.jpg
# D:\WORKSHOP2\100-200Sec_model\120.jpg
# ...

# %%
width = 800
height = 800

# %%
os.mkdir('D:\\WORKSHOP2\\100-200Sec_model4\\')

# %%
for img in fileName:

    pic = Image.open('D:\\WORKSHOP2\\100-200Sec_model\\' + img)

    newpic = pic.resize((width, height),Image.ANTIALIAS)

    print (newpic)

    newpic.save('D:\\WORKSHOP2\\100-200Sec_model4\\'+img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB1165048>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB0FCF7F0>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB1044828>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB107A898>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB1165048>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB0FCF7F0>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB1044828>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB1044A58>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB0FEF5F8>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB0FCF7F0>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB1044828>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB0FCF7F0>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB0FEF5F8>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB0FCF7F0>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x19FB1044828>
# ...
